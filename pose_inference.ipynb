# %%
from setuptools.sandbox import save_path
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-pose.pt")  # load an official model
# Predict with the model

folder = '/home/selim/opencap-mono/LabValidation_withVideos1/subject2/VideoData/Session1/Cam3/walkingTS1/'
path = 'walkingTS1.avi'
video_path = folder + path
output_path = folder + 'output_pose.mp4'

results = model(video_path, save=True, show=True)  # predict on an image
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
# OpenCV(4.10.0) /io/opencv/modules/highgui/src/window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# ...

# %%
model.export(format="coreml")
# Out:
# Ultralytics 8.3.23 🚀 Python-3.10.12 torch-2.5.0+cu124 CPU (Intel Core(TM) i9-14900K)
#
# PyTorch: starting from 'yolo11n-pose.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 56, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['coremltools>=7.0'] not found, attempting AutoUpdate...
# ...
#   Obtaining dependency information for coremltools>=7.0 from https://files.pythonhosted.org/packages/ef/ef/9ae07aa8feace816c7337ff62742f0616364d4f898f77e94dfaf6609597c/coremltools-8.0-cp310-none-manylinux1_x86_64.whl.metadata
# ...
#   Obtaining dependency information for protobuf>=3.1.0 from https://files.pythonhosted.org/packages/5d/ae/3257b09328c0b4e59535e497b0c7537d4954038bdd53a2f0d2f49d15a7c4/protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for cattrs from https://files.pythonhosted.org/packages/c8/d5/867e75361fc45f6de75fe277dd085627a9db5ebb511a87f27dc1396b5351/cattrs-24.1.2-py3-none-any.whl.metadata
# ...
